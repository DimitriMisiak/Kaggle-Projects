# %%
import numpy as np
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# #### Creating a synthetic regression dataset

# %%
# from sklearn.datasets import make_regression

# X, y, coef = make_regression(
#     n_features=1,
#     coef=True,
#     random_state=0
# )
# X = pd.DataFrame(X)
# y = pd.Series(y)

n_samples = 1000
X = np.linspace(-5, 5, n_samples)
coef = np.random.rand()*10
y = coef * X**2 + np.random.normal(size=n_samples)

# %%
plt.figure()
plt.plot(
    X, y,
    marker='.',
    ls='none'
)
print(coef)
# Out:
# 5.427836115054737

# %% [markdown]
# #### building the neural network

# %%
input_shape = [1,]

from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE
# model = model = keras.Sequential([
#     layers.BatchNormalization(),
#     layers.Dense(units=512),
#     layers.Activation('relu'),
#     layers.Dense(units=1),
# ])

# # Single neuron
# model = keras.Sequential([
#     layers.Dense(units=1),
# ])

# Deep neuron network
model = keras.Sequential([
    layers.BatchNormalization(),
    
    layers.Dense(units=512),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(units=512),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(units=512),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(units=512),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(units=512),
    layers.Activation('relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Dense(units=1),
])

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(
    optimizer=opt,
    loss='mse',
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=100,
    min_delta=0.001,
    restore_best_weights=True,
)

lr_schedule = keras.callbacks.ReduceLROnPlateau(
    patience=10,
    factor=0.5,
    min_lr=0.001,
)

# %%
history = model.fit(
    X, y,
    batch_size=100,
    epochs=1000,
    validation_split=0.2,
    callbacks=[early_stopping, lr_schedule],
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 2s 53ms/step - loss: 1428.3353 - val_loss: 103902.4297
# Epoch 2/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 937.8184 - val_loss: 87051.0469
# Epoch 3/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 705.4075 - val_loss: 6659.1123
# Epoch 4/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 439.2794 - val_loss: 2759.8413
# Epoch 5/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 240.8064 - val_loss: 4400.5142
# Epoch 6/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 79.5069 - val_loss: 8572.6348
# Epoch 7/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 78.5356 - val_loss: 7151.1719
# Epoch 8/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 77.3219 - val_loss: 8284.1836
# Epoch 9/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 64.8011 - val_loss: 9477.4229
# Epoch 10/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 35.9489 - val_loss: 9508.7646
# Epoch 11/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 78.1657 - val_loss: 8794.4521
# Epoch 12/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 63.7363 - val_loss: 8864.6016
# Epoch 13/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 49.3011 - val_loss: 9258.9688
# Epoch 14/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 69.0859 - val_loss: 8371.4609
# Epoch 15/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 51.2467 - val_loss: 8487.0479
# Epoch 16/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 54.5903 - val_loss: 8165.2773
# Epoch 17/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 44.7529 - val_loss: 7870.4146
# Epoch 18/1000
# 8/8 [==============================] - 0s 23ms/step - loss: 44.9734 - val_loss: 7660.6748
# Epoch 19/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 43.1525 - val_loss: 7774.2695
# Epoch 20/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 50.4831 - val_loss: 7541.4951
# Epoch 21/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.3039 - val_loss: 7087.7280
# Epoch 22/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 56.0612 - val_loss: 7179.9980
# Epoch 23/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 33.1840 - val_loss: 7104.5112
# Epoch 24/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.7621 - val_loss: 6825.8379
# Epoch 25/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 61.4564 - val_loss: 6718.8643
# Epoch 26/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 58.1191 - val_loss: 6710.2148
# Epoch 27/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.8252 - val_loss: 6642.9536
# Epoch 28/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 54.2893 - val_loss: 6586.6533
# Epoch 29/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.0061 - val_loss: 6436.2588
# Epoch 30/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 70.2884 - val_loss: 6336.8789
# Epoch 31/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.8584 - val_loss: 6272.1113
# Epoch 32/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 54.1099 - val_loss: 6224.2974
# Epoch 33/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 30.4679 - val_loss: 6126.2939
# Epoch 34/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 39.6735 - val_loss: 5954.7642
# Epoch 35/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.7943 - val_loss: 5960.4448
# Epoch 36/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.1868 - val_loss: 5863.3037
# Epoch 37/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 45.3886 - val_loss: 5717.1675
# Epoch 38/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 36.7870 - val_loss: 5596.5688
# Epoch 39/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 32.9164 - val_loss: 5481.6519
# Epoch 40/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.9072 - val_loss: 5364.1411
# Epoch 41/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.0026 - val_loss: 5284.5552
# Epoch 42/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 67.2253 - val_loss: 5170.8921
# Epoch 43/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 25.4052 - val_loss: 5193.2646
# Epoch 44/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 32.6409 - val_loss: 5057.7905
# Epoch 45/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 41.6025 - val_loss: 4912.5542
# Epoch 46/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 46.9086 - val_loss: 4682.8760
# Epoch 47/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 38.1406 - val_loss: 4542.6206
# Epoch 48/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 48.7430 - val_loss: 4527.4785
# Epoch 49/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 40.4414 - val_loss: 4454.6079
# Epoch 50/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 34.8659 - val_loss: 4358.9888
# Epoch 51/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 39.3557 - val_loss: 4201.1177
# Epoch 52/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 28.0975 - val_loss: 4060.5149
# Epoch 53/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 28.1560 - val_loss: 3863.5576
# Epoch 54/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 45.4371 - val_loss: 3685.6196
# Epoch 55/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 37.0112 - val_loss: 3569.7097
# Epoch 56/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 24.3433 - val_loss: 3493.3782
# Epoch 57/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 53.8282 - val_loss: 3419.1575
# Epoch 58/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 39.6828 - val_loss: 3302.5532
# Epoch 59/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 58.3689 - val_loss: 3242.6975
# Epoch 60/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 49.1829 - val_loss: 3200.4634
# Epoch 61/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 37.6076 - val_loss: 3073.5144
# Epoch 62/1000
# 8/8 [==============================] - 0s 24ms/step - loss: 43.9704 - val_loss: 3013.7263
# Epoch 63/1000
# 8/8 [==============================] - 0s 30ms/step - loss: 30.4125 - val_loss: 2957.9287
# Epoch 64/1000
# 8/8 [==============================] - 0s 26ms/step - loss: 36.7783 - val_loss: 2895.9734
# Epoch 65/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 37.3421 - val_loss: 2795.7366
# Epoch 66/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 56.3413 - val_loss: 2746.4365
# Epoch 67/1000
# 8/8 [==============================] - 0s 28ms/step - loss: 39.7143 - val_loss: 2701.9431
# Epoch 68/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 19.8714 - val_loss: 2616.4255
# Epoch 69/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 62.6175 - val_loss: 2567.9309
# Epoch 70/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 49.1163 - val_loss: 2516.1140
# Epoch 71/1000
# 8/8 [==============================] - 0s 21ms/step - loss: 39.0048 - val_loss: 2376.1592
# Epoch 72/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 41.2782 - val_loss: 2287.7112
# Epoch 73/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 46.6810 - val_loss: 2264.7043
# Epoch 74/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.9058 - val_loss: 2297.6682
# Epoch 75/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 52.8854 - val_loss: 2214.5601
# Epoch 76/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 45.3312 - val_loss: 2046.5490
# Epoch 77/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.5467 - val_loss: 2067.7351
# Epoch 78/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 23.5012 - val_loss: 2118.0850
# Epoch 79/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.6214 - val_loss: 2033.7415
# Epoch 80/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 25.7757 - val_loss: 1980.2325
# Epoch 81/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 44.4004 - val_loss: 1867.3363
# Epoch 82/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.0531 - val_loss: 1733.4990
# Epoch 83/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.1437 - val_loss: 1666.2847
# Epoch 84/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.9121 - val_loss: 1636.7897
# Epoch 85/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 40.3969 - val_loss: 1657.1431
# Epoch 86/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 36.1678 - val_loss: 1641.6658
# Epoch 87/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.1925 - val_loss: 1582.8970
# Epoch 88/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.8742 - val_loss: 1467.9220
# Epoch 89/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.1190 - val_loss: 1390.6162
# Epoch 90/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 45.9699 - val_loss: 1295.8545
# Epoch 91/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 39.2844 - val_loss: 1326.0713
# Epoch 92/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 48.7140 - val_loss: 1347.9617
# Epoch 93/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 44.1962 - val_loss: 1274.2216
# Epoch 94/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.2456 - val_loss: 1265.5563
# Epoch 95/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.7557 - val_loss: 1291.0341
# Epoch 96/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.4086 - val_loss: 1166.9977
# Epoch 97/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.4655 - val_loss: 1052.1790
# Epoch 98/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 30.2538 - val_loss: 1070.4917
# Epoch 99/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 52.2197 - val_loss: 1101.0906
# Epoch 100/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 37.1465 - val_loss: 1046.6577
# Epoch 101/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 32.2256 - val_loss: 1011.5026
# Epoch 102/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.0653 - val_loss: 1064.0386
# Epoch 103/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 30.8208 - val_loss: 1043.9756
# Epoch 104/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 49.8430 - val_loss: 978.6575
# Epoch 105/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.3552 - val_loss: 1020.8965
# Epoch 106/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 31.5406 - val_loss: 992.6765
# Epoch 107/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 27.7566 - val_loss: 972.7928
# Epoch 108/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 31.1166 - val_loss: 1023.7260
# Epoch 109/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 21.3930 - val_loss: 988.0880
# Epoch 110/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 55.2352 - val_loss: 1046.1312
# Epoch 111/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 22.2463 - val_loss: 1150.1252
# Epoch 112/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 69.7424 - val_loss: 1135.1798
# Epoch 113/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 44.2184 - val_loss: 1062.0779
# Epoch 114/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 36.1697 - val_loss: 970.1968
# Epoch 115/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 39.0329 - val_loss: 835.5687
# Epoch 116/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.6410 - val_loss: 884.4523
# Epoch 117/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 73.6724 - val_loss: 867.0337
# Epoch 118/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 55.4679 - val_loss: 970.0522
# Epoch 119/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 36.4191 - val_loss: 915.6697
# Epoch 120/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 56.1772 - val_loss: 968.5000
# Epoch 121/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 30.4752 - val_loss: 890.3564
# Epoch 122/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 40.8900 - val_loss: 851.1649
# Epoch 123/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.2678 - val_loss: 858.8279
# Epoch 124/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 35.3518 - val_loss: 895.5043
# Epoch 125/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 36.0146 - val_loss: 885.7294
# Epoch 126/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 32.8754 - val_loss: 955.1089
# Epoch 127/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.7002 - val_loss: 1141.3363
# Epoch 128/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.3468 - val_loss: 1137.4708
# Epoch 129/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 42.1827 - val_loss: 1116.2762
# Epoch 130/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 31.2990 - val_loss: 1104.2922
# Epoch 131/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 47.3056 - val_loss: 1189.9189
# Epoch 132/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 33.1614 - val_loss: 1072.5535
# Epoch 133/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 21.2336 - val_loss: 978.8372
# Epoch 134/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 56.3567 - val_loss: 921.2961
# Epoch 135/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 38.2806 - val_loss: 859.2287
# Epoch 136/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 30.7596 - val_loss: 882.3484
# Epoch 137/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.4098 - val_loss: 961.7072
# Epoch 138/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.2494 - val_loss: 1024.0219
# Epoch 139/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.3318 - val_loss: 914.7401
# Epoch 140/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 33.8171 - val_loss: 826.8982
# Epoch 141/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.8128 - val_loss: 737.9813
# Epoch 142/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 41.3331 - val_loss: 939.3439
# Epoch 143/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 48.2767 - val_loss: 1061.5797
# Epoch 144/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 44.8589 - val_loss: 1038.9028
# Epoch 145/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 23.5555 - val_loss: 1068.2324
# Epoch 146/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 43.6966 - val_loss: 1062.9868
# Epoch 147/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.6082 - val_loss: 1041.0850
# Epoch 148/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 30.9961 - val_loss: 1016.5714
# Epoch 149/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.9529 - val_loss: 1137.4452
# Epoch 150/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 27.8084 - val_loss: 1162.4471
# Epoch 151/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.4944 - val_loss: 1132.5596
# Epoch 152/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 24.6795 - val_loss: 1106.9801
# Epoch 153/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.1468 - val_loss: 1115.5647
# Epoch 154/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 22.1786 - val_loss: 1124.1469
# Epoch 155/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 46.8898 - val_loss: 1168.1365
# Epoch 156/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.5960 - val_loss: 1111.2644
# Epoch 157/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 23.5360 - val_loss: 1140.4988
# Epoch 158/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 41.7683 - val_loss: 1202.4918
# Epoch 159/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 23.2169 - val_loss: 1216.6820
# Epoch 160/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.9247 - val_loss: 1216.3013
# Epoch 161/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.4713 - val_loss: 1079.0328
# Epoch 162/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 42.0047 - val_loss: 1005.2633
# Epoch 163/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 35.6125 - val_loss: 1074.1824
# Epoch 164/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 35.3173 - val_loss: 1001.9545
# Epoch 165/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 31.3304 - val_loss: 999.5103
# Epoch 166/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 28.2424 - val_loss: 1134.2458
# Epoch 167/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 32.8099 - val_loss: 1065.1697
# Epoch 168/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 47.4904 - val_loss: 1065.4039
# Epoch 169/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 25.5756 - val_loss: 1039.5239
# Epoch 170/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 32.2136 - val_loss: 1002.1478
# Epoch 171/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 39.5165 - val_loss: 1014.6252
# Epoch 172/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.5727 - val_loss: 1118.5824
# Epoch 173/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 40.4392 - val_loss: 1221.1670
# Epoch 174/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 30.0944 - val_loss: 1193.3740
# Epoch 175/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 32.2199 - val_loss: 1215.4928
# Epoch 176/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 28.7155 - val_loss: 1174.9215
# Epoch 177/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 23.9505 - val_loss: 1234.5500
# Epoch 178/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 36.5680 - val_loss: 1163.8628
# Epoch 179/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 44.9353 - val_loss: 1118.5991
# Epoch 180/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.5079 - val_loss: 1065.9501
# Epoch 181/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 25.4881 - val_loss: 1052.1012
# Epoch 182/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 21.2714 - val_loss: 1103.0511
# Epoch 183/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 31.8588 - val_loss: 1142.8912
# Epoch 184/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 28.7359 - val_loss: 1340.2625
# Epoch 185/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 64.8829 - val_loss: 1583.9447
# Epoch 186/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 22.3072 - val_loss: 1555.2172
# Epoch 187/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.9704 - val_loss: 1351.0725
# Epoch 188/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 35.1950 - val_loss: 1281.9971
# Epoch 189/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 34.6905 - val_loss: 1278.8433
# Epoch 190/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.4189 - val_loss: 1325.4939
# Epoch 191/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.2466 - val_loss: 1399.0732
# Epoch 192/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 47.4735 - val_loss: 1464.8799
# Epoch 193/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 41.6771 - val_loss: 1381.6062
# Epoch 194/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.9684 - val_loss: 1393.5247
# Epoch 195/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 31.9114 - val_loss: 1353.0693
# Epoch 196/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 23.4494 - val_loss: 1264.3336
# Epoch 197/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 46.2954 - val_loss: 1296.0208
# Epoch 198/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.9228 - val_loss: 1305.1117
# Epoch 199/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 32.1323 - val_loss: 1301.0724
# Epoch 200/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 35.0735 - val_loss: 1309.5553
# Epoch 201/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.5794 - val_loss: 1348.3320
# Epoch 202/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.7061 - val_loss: 1321.7473
# Epoch 203/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.7659 - val_loss: 1284.5289
# Epoch 204/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.6882 - val_loss: 1200.0825
# Epoch 205/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.0793 - val_loss: 1172.5229
# Epoch 206/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.5233 - val_loss: 1133.8960
# Epoch 207/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.8597 - val_loss: 1224.9342
# Epoch 208/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 32.0124 - val_loss: 1228.7479
# Epoch 209/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 32.3900 - val_loss: 1218.3369
# Epoch 210/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 22.5701 - val_loss: 1316.4436
# Epoch 211/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 25.7173 - val_loss: 1347.2404
# Epoch 212/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.6396 - val_loss: 1327.6743
# Epoch 213/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.2180 - val_loss: 1229.6760
# Epoch 214/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 28.6387 - val_loss: 1221.5197
# Epoch 215/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.3403 - val_loss: 1234.7798
# Epoch 216/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 29.9321 - val_loss: 1200.7482
# Epoch 217/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 31.1977 - val_loss: 1141.7078
# Epoch 218/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 24.6900 - val_loss: 1193.4956
# Epoch 219/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 40.9259 - val_loss: 1236.7308
# Epoch 220/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.2966 - val_loss: 1160.7706
# Epoch 221/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.0680 - val_loss: 1094.8346
# Epoch 222/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.3192 - val_loss: 1167.7438
# Epoch 223/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.6153 - val_loss: 1104.7050
# Epoch 224/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.0251 - val_loss: 1053.2196
# Epoch 225/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 33.7807 - val_loss: 1150.2292
# Epoch 226/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 23.5506 - val_loss: 1256.6003
# Epoch 227/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 43.4625 - val_loss: 1257.1997
# Epoch 228/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 41.4165 - val_loss: 1183.1655
# Epoch 229/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 20.9907 - val_loss: 1194.5079
# Epoch 230/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 34.2370 - val_loss: 1232.3032
# Epoch 231/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 59.0134 - val_loss: 1232.4658
# Epoch 232/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 25.2275 - val_loss: 1240.6351
# Epoch 233/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 34.3758 - val_loss: 1198.3007
# Epoch 234/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.1119 - val_loss: 1187.1676
# Epoch 235/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 35.1442 - val_loss: 1234.9156
# Epoch 236/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 26.8069 - val_loss: 1336.7897
# Epoch 237/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 20.0913 - val_loss: 1355.3002
# Epoch 238/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 29.8880 - val_loss: 1341.5023
# Epoch 239/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 38.6549 - val_loss: 1436.7124
# Epoch 240/1000
# 8/8 [==============================] - 0s 20ms/step - loss: 34.5495 - val_loss: 1482.6938
# Epoch 241/1000
# 8/8 [==============================] - 0s 19ms/step - loss: 51.0203 - val_loss: 1503.6904

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Loss: {:0.4f}".format(history_df['val_loss'].min()));
# history_df.loc[:, ['loss',]].plot()
# print("Minimum Loss: {:0.4f}".format(history_df['loss'].min()));
history_df.loc[:, ['lr']].plot()
# Out:
# Minimum Loss: 737.9813
# <AxesSubplot:>

# %%
import tensorflow as tf
# x = tf.linspace(X.min()*1.5, X.max()*1.5, 100)
x = tf.linspace(-5, 5, 100)
y_preds = model.predict(x)

plt.figure(dpi=100)

# dataset
plt.plot(
    X, y,
    marker='.', ls='none', ms=1
)
# model
plt.plot(x, y_preds, 'k')

# plt.xlim(-1, 1)
# plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
# Out:
# Text(0, 0.5, 'Target y')

# %%
model.get_weights()

# %%
model.summary()
# Out:
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_87 (Batc (None, 1)                 4
# _________________________________________________________________
# dense_141 (Dense)            (None, 512)               1024
# _________________________________________________________________
# activation_72 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_88 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_142 (Dense)            (None, 256)               131328
# _________________________________________________________________
# activation_73 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_89 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_143 (Dense)            (None, 128)               32896
# _________________________________________________________________
# activation_74 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_90 (Batc (None, 128)               512
# _________________________________________________________________
# dense_144 (Dense)            (None, 64)                8256
# _________________________________________________________________
# activation_75 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_91 (Batc (None, 64)                256
# _________________________________________________________________
# dense_145 (Dense)            (None, 32)                2080
# _________________________________________________________________
# activation_76 (Activation)   (None, 32)                0
# _________________________________________________________________
# batch_normalization_92 (Batc (None, 32)                128
# _________________________________________________________________
# dense_146 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 179,589
# Trainable params: 177,603
# Non-trainable params: 1,986
# _________________________________________________________________

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x15642727100>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15643a75f10>,
#  <tensorflow.python.keras.layers.core.Activation at 0x15643a758e0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x1564399b160>,
#  <tensorflow.python.keras.layers.core.Dense at 0x156409dfd60>,
#  <tensorflow.python.keras.layers.core.Activation at 0x156439e74f0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x156439e7550>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15643a6dc10>,
#  <tensorflow.python.keras.layers.core.Activation at 0x156407511f0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x1564206d940>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15643a09970>,
#  <tensorflow.python.keras.layers.core.Activation at 0x15643a8a040>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x15643a8a1c0>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15643a8a2e0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x15643a8a7c0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x15643a8a940>,
#  <tensorflow.python.keras.layers.core.Dense at 0x15643a8aa60>]

# %%
xx = np.linspace(-5, 5, 100)

yy0 = yy = np.expand_dims(xx, 1)

for layer in model.layers[:-1]:
    fig, axes = plt.subplots(ncols=2)
    yy = layer(yy0)
    axes[0].plot(xx, yy)
    axes[1].plot(yy0, yy)
    yy0 = yy

layer = model.layers[-1]
fig, axes = plt.subplots(ncols=2)
yy = layer(yy0)
axes[0].plot(xx, yy, color='k')
axes[0].plot(xx, yy0*layer.get_weights()[0][0])
axes[0].axhline(layer.get_weights()[1][0], color='k', ls='--')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-696-54dd484cbb37> in <module>
#       7     yy = layer(yy0)
#       8     axes[0].plot(xx, yy)
# ----> 9     axes[1].plot(yy0, yy)
#      10     yy0 = yy
#      11
#
# E:\Projects\Kaggle-Projects\env\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# E:\Projects\Kaggle-Projects\env\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# E:\Projects\Kaggle-Projects\env\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     415         ncx, ncy = x.shape[1], y.shape[1]
#     416         if ncx > 1 and ncy > 1 and ncx != ncy:
# --> 417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
#     418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#
# ValueError: x has 512 columns but y has 256 columns

# %%
layer.get_weights()
